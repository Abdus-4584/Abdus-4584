# %%
import pyodbc
import pandas as pd
import adal

# %%
# Connecting to DB TEST
server ="test41-eus2-ins-sqlepi-orderinteraction.database.windows.net"
database="FreshRWOAPIBufferTestDB" 
username="abdus.samad@kroger.com"
Authentication='ActiveDirectoryInteractive'
src_conn = pyodbc.connect(
        "DRIVER={ODBC Driver 17 for SQL Server};SERVER="
        + server
        + ";DATABASE="
        + database
        + ";UID="
        + username
        + ";AUTHENTICATION="
        + Authentication
    )
print("\n\nConnected to Database.")
# Out:
# Connected to Database.

# %%
# Define columns to compare
cols_to_compare = ["TRIM(C.CON_DSC_TX) AS ItemDescription",                   
                   "D.CON_TYP_CD AS UPC_Type",                   
                   "CASE WHEN G.FYT_SUB_DPT_ID = 10 THEN 10 WHEN G.FYT_SUB_DPT_ID = 15 THEN 15 WHEN G.FYT_SUB_DPT_ID in (09,46,47,54) THEN 09 END AS DepartmentNumber",                    
                   "H.FYT_SUB_DPT_CD AS MerchandisingFamilyNumber",                    
                   "G.FYT_COM_CD AS MerchandisingCategoryNumber",                    
                   "B.QPS_SCN_CD AS ScanCode",]

# %%
# Define table names
table_names =  ['[dbo].[NRM_CON_UPC_STO_PRC_034]'
,'[dbo].[NRM_CON_UPC_STO_PRC_014]'
,'[dbo].[NRM_CON_UPC_STO_PRC_011]'
,'[dbo].[NRM_CON_UPC_STO_PRC_021]'
,'[dbo].[NRM_CON_UPC_STO_PRC_016]'
,'[dbo].[NRM_CON_UPC_STO_PRC_018]'
,'[dbo].[NRM_CON_UPC_STO_PRC_024]'
,'[dbo].[NRM_CON_UPC_STO_PRC_025]'
,'[dbo].[NRM_CON_UPC_STO_PRC_026]'
,'[dbo].[NRM_CON_UPC_STO_PRC_029]'
,'[dbo].[NRM_CON_UPC_STO_PRC_035]'
,'[dbo].[NRM_CON_UPC_STO_PRC_531]'
,'[dbo].[NRM_CON_UPC_STO_PRC_534]'
,'[dbo].[NRM_CON_UPC_STO_PRC_615]'
,'[dbo].[NRM_CON_UPC_STO_PRC_620]'
,'[dbo].[NRM_CON_UPC_STO_PRC_660]'
,'[dbo].[NRM_CON_UPC_STO_PRC_701]'
,'[dbo].[NRM_CON_UPC_STO_PRC_703]'
,'[dbo].[NRM_CON_UPC_STO_PRC_704]'
,'[dbo].[NRM_CON_UPC_STO_PRC_705]'
,'[dbo].[NRM_CON_UPC_STO_PRC_706]'
,'[dbo].[NRM_CON_UPC_STO_PRC_708]']

# %%
import warnings

warnings.filterwarnings('ignore')

# %%
#Run dataset for Sellable Item list provided 'Sellable_upc_OI_Task1'
common_upcs = ['0084013430245' ,'0084013430263' ,'0084013430243' ,'0084013430262' ,'0084013430133' ,'0084013430129' ,'0084013430261' ,'0084013430132' ,'0084013430255' ,'0084013430138' ,'0084013430257' ,'0084013430491' ,'0084013430569' ,'0084013430136' ,'0084013430567' ,'0084013430142' ,'0084013430141' ,'0084013430146' ,'0084013430365' ,'0084013430264' ,'0084013430735' ,'0084013430149' ,'0084013430145' ,'0084013430528' ,'0084013430368' ,'0084013430579' ,'0084013430738' ,'0084013430527' ,'0084013430452' ,'0001111039611' ,
# %%
# Convert common_upcs to a list of quoted strings
quoted_upcs = [f"'{upc}'" for upc in common_upcs]

# %%
print("Number of common UPCs: ", len(common_upcs))
common_upcs_15 = common_upcs[:15]
print(common_upcs_15)
# Out:
# Number of common UPCs:  2264
# ['0084013430245', '0084013430263', '0084013430243', '0084013430262', '0084013430133', '0084013430129', '0084013430261', '0084013430132', '0084013430255', '0084013430138', '0084013430257', '0084013430491', '0084013430569', '0084013430136', '0084013430567']

# %%
# Define empty list to store dataframes for each table
df_list = []
# Loop through each table to fetch data for common UPCs
for table in table_names:
    query = f"""
    SELECT DISTINCT {table}.CON_UPC_NO, {','.join(cols_to_compare)} 
    FROM {table} 
    INNER JOIN NRM_BAS_UPC B ON {table}.BAS_UPC_ID = B.BAS_UPC_ID 
    INNER JOIN NRM_CON_UPC C ON B.CON_UPC_NO = C.CON_UPC_NO 
    INNER JOIN NRM_CAS_CON_UPC D ON C.CON_UPC_ID = D.CON_UPC_ID 
    INNER JOIN NRM_CAS_UPC E ON D.CAS_UPC_ID = E.CAS_UPC_ID 
    INNER JOIN NRM_FYT_SCM F ON E.FYT_SUB_COM_ID = F.FYT_SUB_COM_ID 
    INNER JOIN NRM_FYT_COM G ON G.FYT_COM_ID = F.FYT_COM_ID 
    INNER JOIN NRM_FYT_SUB_DPT H ON H.FYT_SUB_DPT_ID = G.FYT_SUB_DPT_ID 
    INNER JOIN NRM_FYT_REC_DPT I ON I.FYT_REC_DPT_ID = H.FYT_REC_DPT_ID 
    INNER JOIN NRM_BAS_CON_MDV J ON B.BAS_UPC_ID = J.BAS_UPC_ID 
    WHERE G.FYT_SUB_DPT_ID = 10 
    AND {table}.CON_ITM_STU_CD IN ('I', 'A') 
    AND (D.CON_TYP_CD = 'F' OR D.CON_TYP_CD IS NULL) 
    AND B.QPS_SCN_CD = 'W' AND I.FYT_REC_DPT_CD IN ('15','56','73') AND G.FYT_COM_CD IN ('450','451','463','456','457')
    AND {table}.CON_UPC_NO IN ({','.join(quoted_upcs)})
        """
    df = pd.read_sql(query, src_conn)
    #df['table_names'] = table
    df_list.append(df)
    print("Query run complete!!")
# Out:
# Query run complete!!
# Query run complete!!
# Query run complete!!
# Query run complete!!
# Query run complete!!
# Query run complete!!
# Query run complete!!
# Query run complete!!
# Query run complete!!
# Query run complete!!
# Query run complete!!
# Query run complete!!
# Query run complete!!
# Query run complete!!
# Query run complete!!
# Query run complete!!
# Query run complete!!
# Query run complete!!
# Query run complete!!
# Query run complete!!
# Query run complete!!
# Query run complete!!

# %%
# Merge dataframes on UPC column
df_merged = pd.concat(df_list).reset_index(drop=True)
# Group by UPC and compare values
df_grouped = df_merged.groupby('CON_UPC_NO',).nunique().max(axis=1)[1:]

# %%
# Combine all dataframes into a single dataframe
df = pd.concat(df_list)

# %%
# Group the data by UPC and compare the values for each column --RUN!
grouped = df.groupby('CON_UPC_NO',)
mismatches = []
for upc, group in grouped:
    ref_row = group.iloc[0]
    for _, row in group.iterrows():
        if not ref_row.equals(row.fillna(ref_row)):
            mismatches.append(upc)

if not mismatches:
    print("All data matches.")
else:
    print("Data mismatches found:")
    for upc in set(mismatches):
        print(f"UPC {upc} has mismatches in table.") #Code END!!
# Out:
# All data matches.

# %%
# Group the data by UPC and compare the values for each column
#grouped = df.groupby('CON_UPC_NO',)
#mismatches = []
#for upc, group in grouped:
    #ref_row = group.iloc[0]
    #for _, row in group.iterrows():
        #if not all(row == ref_row):
            #mismatches.append(upc)

#if not mismatches:
    #print("All data matches.")
#else:
    #print("Data mismatches found:")
    #for upc in set(mismatches):
        #print(f"UPC {upc} has mismatches in table.")

# %%
#get mismatch for only XXX mismatch Items. so that dataset is sorted and in one place.
common_upcs =

# %%
# Convert common_upcs to a list of quoted strings
quoted_upcs = [f"'{upc}'" for upc in common_upcs]
print("Number of common UPCs: ", len(common_upcs))
common_upcs_15 = common_upcs[:15]
print(common_upcs_15)
# Out:
# Number of common UPCs:  2264
# ['0084013430245', '0084013430263', '0084013430243', '0084013430262', '0084013430133', '0084013430129', '0084013430261', '0084013430132', '0084013430255', '0084013430138', '0084013430257', '0084013430491', '0084013430569', '0084013430136', '0084013430567']

# %%
# Define empty list to store dataframes for each table, Add table name here.
df_list = []
# Loop through each table to fetch data for common UPCs
for table in table_names:
    query = f"""
    SELECT DISTINCT {table}.CON_UPC_NO, {','.join(cols_to_compare)} 
    FROM {table} 
    INNER JOIN NRM_BAS_UPC B ON {table}.BAS_UPC_ID = B.BAS_UPC_ID 
    INNER JOIN NRM_CON_UPC C ON B.CON_UPC_NO = C.CON_UPC_NO 
    INNER JOIN NRM_CAS_CON_UPC D ON C.CON_UPC_ID = D.CON_UPC_ID 
    INNER JOIN NRM_CAS_UPC E ON D.CAS_UPC_ID = E.CAS_UPC_ID 
    INNER JOIN NRM_FYT_SCM F ON E.FYT_SUB_COM_ID = F.FYT_SUB_COM_ID 
    INNER JOIN NRM_FYT_COM G ON G.FYT_COM_ID = F.FYT_COM_ID 
    INNER JOIN NRM_FYT_SUB_DPT H ON H.FYT_SUB_DPT_ID = G.FYT_SUB_DPT_ID 
    INNER JOIN NRM_FYT_REC_DPT I ON I.FYT_REC_DPT_ID = H.FYT_REC_DPT_ID 
    INNER JOIN NRM_BAS_CON_MDV J ON B.BAS_UPC_ID = J.BAS_UPC_ID 
    WHERE G.FYT_SUB_DPT_ID = 10 
    AND {table}.CON_ITM_STU_CD IN ('I', 'A') 
    AND (D.CON_TYP_CD = 'F' OR D.CON_TYP_CD IS NULL) 
    AND B.QPS_SCN_CD = 'W' AND I.FYT_REC_DPT_CD IN ('15','56','73') AND G.FYT_COM_CD IN ('450','451','463','456','457')
    AND {table}.CON_UPC_NO IN ({','.join(quoted_upcs)})
        """
    df = pd.read_sql(query, src_conn)
    df['table_names'] = table
    df_list.append(df)
    print("Query run complete!!")
# Out:
# Query run complete!!
# Query run complete!!
# Query run complete!!
# Query run complete!!
# Query run complete!!
# Query run complete!!
# Query run complete!!
# Query run complete!!
# Query run complete!!
# Query run complete!!
# Query run complete!!
# Query run complete!!
# Query run complete!!
# Query run complete!!
# Query run complete!!
# Query run complete!!
# Query run complete!!
# Query run complete!!
# Query run complete!!
# Query run complete!!
# Query run complete!!
# Query run complete!!

# %%
# Merge dataframes on UPC column
df_merged = pd.concat(df_list).reset_index(drop=True)
# Group by UPC and compare values
df_grouped = df_merged.groupby('CON_UPC_NO',).nunique().max(axis=1)[1:]

# %%
# Combine all dataframes into a single dataframe
df = pd.concat(df_list)

# %%
# Sort the final dataframe by 'CON_UPC_NO'
df = df.sort_values(['CON_UPC_NO','table_names'])

# %%
df.to_csv("C:\\Users\\AS81970\\Desktop\\Sellable_output_with_table.csv", index=False)
