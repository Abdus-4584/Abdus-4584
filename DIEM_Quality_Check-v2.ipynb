# %%
import pandas as pd

# %%
import re
import datetime

# %%
file1 = "C:\\Users\\AS81970\\Desktop\\Q1 2023\\DIEM_DSA_Code\\101_Daily_Sales_Sample.csv"

# %%
df1= pd.read_csv(file1)

# %%
with open("C:\\Users\\AS81970\\Desktop\\Q1 2023\\DIEM_DSA_Code\\101_Daily_Sales_Sample.csv") as file:
    num_lines = sum(1 for line in file)
    print(f"Number of lines: {num_lines}")
# Out:
# Number of lines: 150

# %%
#df1

# %%
# Quality Checks_Updated 03/09/2023
with open('C:\\Users\\AS81970\\Desktop\\Q1 2023\\DIEM_DSA_Code\\DIEM_Qulaity_Check_reportv2.txt', 'w') as f:
    for i, row in df1.iterrows():
        if pd.isnull(row['CUSTOMER_ORG']):
            print(f"Quality Check CUSTOMER_ORG_CMP_EmptyChk FAILED at row {i}: {row}")
    
        if pd.isnull(row['CUST_STORE']):
            print(f"Quality Check CUST_STORE_CMP_EmptyChk FAILED at row {i}: {row}")
    
        if pd.isnull(row['ITEM_CONSUMER_UPC']):
            print(f"Quality Check ITEM_CONSUMER_UPC_CMP_EmptyChk FAILED at row {i}: {row}")
    
        if pd.isnull(row['POS_DATE']):
            print(f"Quality Check POS_DATE_CMP_EmptyChk FAILED at row {i}: {row}")
    
        if pd.isnull(row['POS_DOL_AMOUNT']):
            print(f"Quality Check POS_DOL_AMOUNT_CMP_EmptyChk FAILED at row {i}: {row}")
    
        if pd.isnull(row['POS_POUNDS']):
            print(f"Quality Check POS_POUNDS_CMP_EmptyChk FAILED at row {i}: {row}")
    
        if pd.isnull(row['POS_UNITS']):
            print(f"Quality Check POS_UNITS_CMP_EmptyChk FAILED at row {i}: {row}")
    
        if pd.notnull(row['POS_DOL_AMOUNT']):
            if not re.match("^-?\d*\.?\d+$", str(row['POS_DOL_AMOUNT'])):
                print(f"Quality Check POS_DOL_AMOUNT_CON_NumericChk FAILED at row {i}: {row}")    
            
        if pd.notnull(row['POS_POUNDS']):
            if not re.match("^\d*\.?\d+$", str(row['POS_POUNDS'])):
                print(f"Quality Check POS_POUNDS_CON_NumericChk FAILED at row {i}: {row}")    
            
        if pd.notnull(row['POS_UNITS']):
            if not re.match("^\d*\.?\d+$", str(row['POS_UNITS'])):
        #if not re.match("^\d+$", str(row['POS_UNITS'])):
                print(f"Quality Check POS_UNITS_CON_NumericChk FAILED at row {i}: {row}")             
            
    print("Quality check completed.")
# Out:
# Quality Check CUSTOMER_ORG_CMP_EmptyChk FAILED at row 0: CUSTOMER_ORG                  NaN
# CUST_STORE                    NaN
# ITEM_CONSUMER_UPC             NaN
# POS_DATE                1/30/2023
# POS_DOL_AMOUNT              23.19
# POS_POUNDS                     40
# POS_UNITS                      17
# POS_UOM                     lb_av
# ITEM_SRC_DIV                 90.0
# ITEM_SRC_LOC                205.0
# MODALITY                  INSTORE
# FULFILLMENT          INSTACARTPBI
# UPC_TYPE                        I
# Name: 0, dtype: object
# Quality Check CUST_STORE_CMP_EmptyChk FAILED at row 0: CUSTOMER_ORG                  NaN
# CUST_STORE                    NaN
# ITEM_CONSUMER_UPC             NaN
# POS_DATE                1/30/2023
# POS_DOL_AMOUNT              23.19
# POS_POUNDS                     40
# POS_UNITS                      17
# POS_UOM                     lb_av
# ITEM_SRC_DIV                 90.0
# ITEM_SRC_LOC                205.0
# ...

# %%
# Quality Checks
now = datetime.datetime.now()
timestamp = now.strftime("%Y-%m-%d") #now.strftime("%Y-%m-%d_%H-%M-%S")

filename = f"C:\\Users\\AS81970\\Desktop\\Q1 2023\\DIEM_DSA_Code\\Reports\\DIEM_Qulaity_Check_report_v2_{timestamp}.txt"

with open(filename, "w") as f:
    for i, row in df1.iterrows():
        if pd.isnull(row['CUSTOMER_ORG']):
            f.write(f"Quality Check CUSTOMER_ORG_CMP_NotNullChk FAILED at row {i}: {row}")
    
        if pd.isnull(row['CUST_STORE']):
            f.write(f"Quality Check CUST_STORE_CMP_EmptyChk FAILED at row {i}: {row}")
    
        if pd.isnull(row['ITEM_CONSUMER_UPC']):
            f.write(f"Quality Check ITEM_CONSUMER_UPC_CMP_EmptyChk FAILED at row {i}: {row}")
    
        if pd.isnull(row['POS_DATE']):
            f.write(f"Quality Check POS_DATE_CMP_EmptyChk FAILED at row {i}: {row}")
    
        if pd.isnull(row['POS_DOL_AMOUNT']):
            f.write(f"Quality Check POS_DOL_AMOUNT_CMP_EmptyChk FAILED at row {i}: {row}")
    
        if pd.isnull(row['POS_POUNDS']):
            f.write(f"Quality Check POS_POUNDS_CMP_EmptyChk FAILED at row {i}: {row}")
    
        if pd.isnull(row['POS_UNITS']):
            f.write(f"Quality Check POS_UNITS_CMP_EmptyChk FAILED at row {i}: {row}")
    
        if pd.notnull(row['POS_DOL_AMOUNT']):
            if not re.match("^-?\d*\.?\d+$", str(row['POS_DOL_AMOUNT'])):
                f.write(f"Quality Check POS_DOL_AMOUNT_CON_NumericChk FAILED at row {i}: {row}")    
            
        if pd.notnull(row['POS_POUNDS']):
            if not re.match("^\d*\.?\d+$", str(row['POS_POUNDS'])):
                f.write(f"Quality Check POS_POUNDS_CON_NumericChk FAILED at row {i}: {row}")    
            
        if pd.notnull(row['POS_UNITS']):
            if not re.match("^\d*\.?\d+$", str(row['POS_UNITS'])):
        #if not re.match("^\d+$", str(row['POS_UNITS'])):
                f.write(f"Quality Check POS_UNITS_CON_NumericChk FAILED at row {i}: {row}")             
            
    print("Quality check completed.")
# Out:
# Quality check completed.
